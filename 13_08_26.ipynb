# %% [markdown]
# <a href="https://colab.research.google.com/github/sonam2006-sandanshiv/microsoft-workshop/blob/main/13_08_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
a1=df= pd.DataFrame({
    "Name":["john","Alice","Bob"],
    "Marks":[40,30,20]
})

# %%
a1
# Out:
#     Name  Marks
# 0   john     40
# 1  Alice     30
# 2    Bob     20

# %%
a1["Grade"]=["O","A","B"]
a1.sort_values("Marks")
# Out:
#     Name  Marks Grade
# 2    Bob     20     B
# 1  Alice     30     A
# 0   john     40     O

# %%
a1.sort_values("Marks",ascending=False)
# Out:
#     Name  Marks Grade
# 0   john     40     O
# 1  Alice     30     A
# 2    Bob     20     B

# %%
a1.sort_values("Name")
# Out:
#     Name  Marks Grade
# 1  Alice     30     A
# 2    Bob     20     B
# 0   john     40     O

# %%
a1[["Name","Marks"]]
# Out:
#     Name  Marks
# 0   john     40
# 1  Alice     30
# 2    Bob     20

# %%
df=pd.read_csv("/content/clientes (2).csv")

# %%
df.head()
# Out:
#   cod_cliente  sexo estado_civil dependentes      educacao empregado  renda  \
# 0    LP001002  Male           No           0      Graduate        No   5849
# 1    LP001003  Male          Yes           1      Graduate        No   4583
# 2    LP001005  Male          Yes           0      Graduate       Yes   3000
# 3    LP001006  Male          Yes           0  Not Graduate        No   2583
# 4    LP001008  Male           No           0      Graduate        No   6000
#
#   renda_conjuge  emprestimo  prestacao_mensal  historico_credito imovel  \
# 0             0         NaN             360.0                1.0  Urban
# 1          1508       128.0             360.0                1.0  Rural
# 2             0        66.0             360.0                1.0  Urban
# 3          2358       120.0             360.0                1.0  Urban
# 4             0       141.0             360.0                1.0  Urban
#
#   aprovacao_emprestimo
# 0                    Y
# 1                    N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   cod_cliente           614 non-null    object
#  1   sexo                  601 non-null    object
#  2   estado_civil          611 non-null    object
#  3   dependentes           599 non-null    object
#  4   educacao              614 non-null    object
#  5   empregado             582 non-null    object
#  6   renda                 614 non-null    int64
#  7   renda_conjuge         614 non-null    object
#  8   emprestimo            592 non-null    float64
#  9   prestacao_mensal      600 non-null    float64
#  10  historico_credito     564 non-null    float64
#  11  imovel                614 non-null    object
#  12  aprovacao_emprestimo  614 non-null    object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 62.5+ KB

# %%
df["sexo"]=df["sexo"].fillna("Male")

# %%
df["dependentes"].mode()
# Out:
# 0    0
# Name: dependentes, dtype: object

# %%
df["dependentes"].value_counts()
# Out:
# dependentes
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
df["dependentes"]=df["dependentes"].fillna(0)

# %%
df["historico_credito"]=df["historico_credito"].fillna(0)

# %%
df["emprestimo"].median(0)
# Out:
# 128.0

# %%
df["emprestimo"]=df["emprestimo"].fillna(128.0)

# %%
df["empregado"].mode()
# Out:
# 0    No
# Name: empregado, dtype: object

# %%
df["empregado"]=df["empregado"].fillna("No")

# %%
df["estado_civil"].mode()
# Out:
# 0    Yes
# Name: estado_civil, dtype: object

# %%
df["estado_civil"]=df["estado_civil"].fillna("No")

# %%
df["prestacao_mensal"].median()
# Out:
# 360.0

# %%
df["prestacao_mensal"]=df["prestacao_mensal"].fillna(360.0)

# %%
df.isnull().sum()
# Out:
# cod_cliente             0
# sexo                    0
# estado_civil            0
# dependentes             0
# educacao                0
# empregado               0
# renda                   0
# renda_conjuge           0
# emprestimo              0
# prestacao_mensal        0
# historico_credito       0
# imovel                  0
# aprovacao_emprestimo    0
# dtype: int64

# %%
del df ["cod_cliente"]

# %%
df.shape
# Out:
# (614, 12)

# %%
df.head()
# Out:
#    sexo estado_civil dependentes      educacao empregado  renda renda_conjuge  \
# 0  Male           No           0      Graduate        No   5849             0
# 1  Male          Yes           1      Graduate        No   4583          1508
# 2  Male          Yes           0      Graduate       Yes   3000             0
# 3  Male          Yes           0  Not Graduate        No   2583          2358
# 4  Male           No           0      Graduate        No   6000             0
#
#    emprestimo  prestacao_mensal  historico_credito imovel aprovacao_emprestimo
# 0       128.0             360.0                1.0  Urban                    Y
# 1       128.0             360.0                1.0  Rural                    N
# 2        66.0             360.0                1.0  Urban                    Y
# 3       120.0             360.0                1.0  Urban                    Y
# 4       141.0             360.0                1.0  Urban                    Y

# %%
df["sexo"].value_counts()
# Out:
# sexo
# Male      502
# Female    112
# Name: count, dtype: int64

# %%
df["educacao"].value_counts()
# Out:
# educacao
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
len(df.query(" sexo=='Male' and educacao=='Graduate' "))
# Out:
# 388

# %%
len(df.query(" imovel=='Urban' and aprovacao_emprestimo=='Y' and renda>=3000 "))
# Out:
# 96

# %%
#rent collected on the basis of
df.groupby("renda")["imovel"].min()
# Out:
# renda
# 150          Rural
# 210      Semiurban
# 416          Urban
# 645          Rural
# 674          Rural
#            ...
# 39147    Semiurban
# 39999    Semiurban
# 51763        Urban
# 63337        Urban
# 81000        Rural
# Name: imovel, Length: 505, dtype: object

# %%
df.groupby('dependentes')["emprestimo"].sum().sort_values()
# Out:
# dependentes
# 0      1925.0
# 3+     9610.0
# 2     15106.0
# 1     16057.0
# 0     46794.0
# Name: emprestimo, dtype: float64

# %%
df.groupby('dependentes')["emprestimo"].sum().sort_values(ascending=False)
# Out:
# dependentes
# 0     46794.0
# 1     16057.0
# 2     15106.0
# 3+     9610.0
# 0      1925.0
# Name: emprestimo, dtype: float64

# %%
df.groupby('dependentes')["emprestimo"].sum().sort_values(ascending=False)[:2]
# Out:
# dependentes
# 0    46794.0
# 1    16057.0
# Name: emprestimo, dtype: float64

# %%
#pd.crosstab ,pd.pivot_table,np.isin,
